# %%
# %reset -f

# %% [markdown]
# pip install pandas beancount matplotlib seaborn

# %%
from beancount.loader import load_file
import pandas as pd

entries, _, _ = load_file("./tab-data/ledger/dynamic.beancount")

txns = []
for entry in entries:
    if entry.__class__.__name__ == "Transaction":
        txn_id = id(entry)  # new unique ID for this transaction
        for posting in entry.postings:
            txns.append({
                "transaction_id": txn_id,
                "date": entry.date,
                "narration": entry.narration,
                "meta": entry.meta,
                "account": posting.account,
                "units": posting.units.number,
                "currency": posting.units.currency,
            })

df = pd.DataFrame(txns)

# %%
df
# Out:
#          transaction_id        date  \
# 0       136912656992176  1970-01-01
# 1       136912656992176  1970-01-01
# 2       136912657006064  1970-01-01
# 3       136912657006064  1970-01-01
# 4       136912657004272  1970-01-01
# ...                 ...         ...
# 100120  136912751826128  2025-05-29
# 100121  136912751826912  2025-05-29
# 100122  136912751826912  2025-05-29
# 100123  136912751826912  2025-05-29
# 100124  136912751826912  2025-05-29
#
#                                                 narration  \
# 0       Initial balance transfer for Liabilities:Bar:M...
# 1       Initial balance transfer for Liabilities:Bar:M...
# 2       Initial balance transfer for Liabilities:Bar:M...
# 3       Initial balance transfer for Liabilities:Bar:M...
# 4       Initial balance transfer for Liabilities:Bar:M...
# ...                                                   ...
# 100120                  Gust gave DJefke a gift of €41.70
# 100121                     Mateo bought 1 items for €1.50
# 100122                     Mateo bought 1 items for €1.50
# 100123                     Mateo bought 1 items for €1.50
# 100124                     Mateo bought 1 items for €1.50
#
#                                                      meta  \
# 0       {'filename': '/mnt/c/Repos/home/hackerspace/ba...
# 1       {'filename': '/mnt/c/Repos/home/hackerspace/ba...
# 2       {'filename': '/mnt/c/Repos/home/hackerspace/ba...
# 3       {'filename': '/mnt/c/Repos/home/hackerspace/ba...
# 4       {'filename': '/mnt/c/Repos/home/hackerspace/ba...
# ...                                                   ...
# 100120  {'filename': '/mnt/c/Repos/home/hackerspace/ba...
# 100121  {'filename': '/mnt/c/Repos/home/hackerspace/ba...
# 100122  {'filename': '/mnt/c/Repos/home/hackerspace/ba...
# 100123  {'filename': '/mnt/c/Repos/home/hackerspace/ba...
# 100124  {'filename': '/mnt/c/Repos/home/hackerspace/ba...
#
#                                  account   units currency
# 0       Liabilities:Bar:Members:Bloemist    5.30      EUR
# 1                 Assets:InitialBalances   -5.30      EUR
# 2           Liabilities:Bar:Members:Koen   -0.50      EUR
# 3                 Assets:InitialBalances    0.50      EUR
# 4           Liabilities:Bar:Members:Bart  -11.80      EUR
# ...                                  ...     ...      ...
# 100120    Liabilities:Bar:Members:DJefke  -41.70      EUR
# 100121              Assets:Inventory:Bar      -1     SODA
# 100122     Liabilities:Bar:Members:Mateo       1     SODA
# 100123     Liabilities:Bar:Members:Mateo    1.50      EUR
# 100124                        Income:Bar   -1.50      EUR
#
# [100125 rows x 7 columns]

# %% [markdown]
# # Examining columns

# %%
for column in df.columns:
    try:
        unique_count = df[column].nunique()
    except TypeError:
        unique_count = df[column].apply(lambda x: str(x)).nunique()
    print(f"{column}: {unique_count} unique values")
# Out:
# transaction_id: 24761 unique values
# date: 2050 unique values
# narration: 9383 unique values
# meta: 24761 unique values
# account: 90 unique values
# units: 847 unique values
# currency: 81 unique values

# %% [markdown]
# # Get rid of meta column

# %%
# Show first row
first_row = df.iloc[1000]
# print(first_row)

# Show shortened meta (first 100 chars)
meta_short = str(first_row['meta'])
print(meta_short)
# Out:
# {'filename': '/mnt/c/Repos/home/hackerspace/bar-graphs/tab-data/ledger/imported-from-spacebar.beancount', 'lineno': 1713, '__tolerances__': {'EUR': Decimal('0.005')}}

# %% [markdown]
# From the meta we ONLY want the type of the purchase

# %%
df['type'] = df['meta'].apply(lambda m: m.get('type') if isinstance(m, dict) else None)
df = df.drop(columns=['meta'])
# Show results
df['type'].unique()
# Out:
# array([None, 'purchase', 'deposit', 'transfer'], dtype=object)

# %%
df
# Out:
#          transaction_id        date  \
# 0       136912656992176  1970-01-01
# 1       136912656992176  1970-01-01
# 2       136912657006064  1970-01-01
# 3       136912657006064  1970-01-01
# 4       136912657004272  1970-01-01
# ...                 ...         ...
# 100120  136912751826128  2025-05-29
# 100121  136912751826912  2025-05-29
# 100122  136912751826912  2025-05-29
# 100123  136912751826912  2025-05-29
# 100124  136912751826912  2025-05-29
#
#                                                 narration  \
# 0       Initial balance transfer for Liabilities:Bar:M...
# 1       Initial balance transfer for Liabilities:Bar:M...
# 2       Initial balance transfer for Liabilities:Bar:M...
# 3       Initial balance transfer for Liabilities:Bar:M...
# 4       Initial balance transfer for Liabilities:Bar:M...
# ...                                                   ...
# 100120                  Gust gave DJefke a gift of €41.70
# 100121                     Mateo bought 1 items for €1.50
# 100122                     Mateo bought 1 items for €1.50
# 100123                     Mateo bought 1 items for €1.50
# 100124                     Mateo bought 1 items for €1.50
#
#                                  account   units currency      type
# 0       Liabilities:Bar:Members:Bloemist    5.30      EUR      None
# 1                 Assets:InitialBalances   -5.30      EUR      None
# 2           Liabilities:Bar:Members:Koen   -0.50      EUR      None
# 3                 Assets:InitialBalances    0.50      EUR      None
# 4           Liabilities:Bar:Members:Bart  -11.80      EUR      None
# ...                                  ...     ...      ...       ...
# 100120    Liabilities:Bar:Members:DJefke  -41.70      EUR  transfer
# 100121              Assets:Inventory:Bar      -1     SODA  purchase
# 100122     Liabilities:Bar:Members:Mateo       1     SODA  purchase
# 100123     Liabilities:Bar:Members:Mateo    1.50      EUR  purchase
# 100124                        Income:Bar   -1.50      EUR  purchase
#
# [100125 rows x 7 columns]

# %% [markdown]
# # Examining transactions
#
# Each transaction is a collection of postings.

# %%
postings_per_transaction = df.groupby("transaction_id").size().reset_index(name="num_postings")

postings_per_transaction = postings_per_transaction.sort_values(
    by='num_postings',
    ascending=False
).reset_index(drop=True)

top_id = postings_per_transaction.iloc[0]["transaction_id"]

postings_per_transaction
# Out:
#         transaction_id  num_postings
# 0      136912891273936            17
# 1      136912788706624            12
# 2      136912855782272            12
# 3      136912867002288            12
# 4      136912704356160            12
# ...                ...           ...
# 24756  136912875339840             2
# 24757  136912875353728             2
# 24758  136912875348464             2
# 24759  136912875501296             2
# 24760  136912875500400             2
#
# [24761 rows x 2 columns]

# %% [markdown]
# Let's look at all postings in this transaction

# %%
df[df["transaction_id"] == top_id]
# Out:
#         transaction_id        date                        narration  \
# 88846  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88847  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88848  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88849  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88850  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88851  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88852  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88853  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88854  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88855  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88856  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88857  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88858  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88859  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88860  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88861  136912891273936  2023-08-03  Els bought 30 items for €118.00
# 88862  136912891273936  2023-08-03  Els bought 30 items for €118.00
#
#                             account    units  currency      type
# 88846          Assets:Inventory:Bar       -1  COCKTAIL  purchase
# 88847   Liabilities:Bar:Members:Els        1  COCKTAIL  purchase
# 88848          Assets:Inventory:Bar       -3    GERMAN  purchase
# 88849   Liabilities:Bar:Members:Els        3    GERMAN  purchase
# 88850          Assets:Inventory:Bar       -6     DUVEL  purchase
# 88851   Liabilities:Bar:Members:Els        6     DUVEL  purchase
# 88852          Assets:Inventory:Bar       -8      CHIP  purchase
# 88853   Liabilities:Bar:Members:Els        8      CHIP  purchase
# 88854          Assets:Inventory:Bar       -8     WATER  purchase
# 88855   Liabilities:Bar:Members:Els        8     WATER  purchase
# 88856          Assets:Inventory:Bar       -3    HOODIE  purchase
# 88857   Liabilities:Bar:Members:Els        3    HOODIE  purchase
# 88858          Assets:Inventory:Bar       -1  PASSPORT  purchase
# 88859   Liabilities:Bar:Members:Els        1  PASSPORT  purchase
# 88860   Liabilities:Bar:Members:Els   118.00       EUR  purchase
# 88861  Liabilities:Bar:Members:Bart    -1.20       EUR  purchase
# 88862                    Income:Bar  -116.80       EUR  purchase

# %% [markdown]
# # Get products

# %%
import yaml

# Load YAML and convert to DataFrame
with open("./tab-data/static/products.yml", "r") as f:
    price_data = yaml.safe_load(f)
df_products = pd.DataFrame(price_data)

# Expand the 'payback' dictionary into its own columns
if 'payback' in df_products.columns:
    payback_df = df_products['payback'].apply(lambda x: x if isinstance(x, dict) else {}).apply(pd.Series)
    payback_df.columns = [f'payback_{col}' for col in payback_df.columns]
    df_products = pd.concat([df_products.drop(columns=['payback']), payback_df], axis=1)

df_products
# Out:
#                       name  price  event_price    currency category visible  \
# 0                     Soda    1.5         2.50        SODA    drink    True
# 1                  Cecemel    0.7         1.00  CHOCO_MILK    drink   False
# 2   Fritz / Club Mate Cola    2.5         3.50      GERMAN    drink    True
# 3                Club Mate    3.0         4.00          CM    drink    True
# 4                      Tea    0.5         0.75         TEA    drink   False
# ..                     ...    ...          ...         ...      ...     ...
# 63                   Pizza    2.5         4.00       PIZZA     food   False
# 64                  SPRITE    2.0         3.00      SPRITE    DRINK   False
# 65                 Cha-Cha    0.5         0.75      CHACHA     food   False
# 66                   Leffe    2.0         3.00       LEFFE  alcohol   False
# 67                   Orval    3.0         4.50        ORVL  alcohol   False
#
#                  payback_account  payback_amount
# 0                            NaN             NaN
# 1                            NaN             NaN
# 2                            NaN             NaN
# 3                            NaN             NaN
# 4                            NaN             NaN
# ..                           ...             ...
# 63  Liabilities:Bar:Members:Yvan             1.5
# 64                           NaN             NaN
# 65                           NaN             NaN
# 66                           NaN             NaN
# 67                           NaN             NaN
#
# [68 rows x 8 columns]

# %% [markdown]
# See all products where a payback is present. This means a member should be paid back every time an items is purchased of this kind.

# %%
df_products[df_products['payback_account'].notna()]
# Out:
#          name  price  event_price   currency category visible  \
# 11  Wristband    1.0          1.5  WRISTBAND     swag    True
# 14   Passport    2.5          3.6   PASSPORT     swag    True
# 15   Postcard    2.5          3.5   POSTCARD      NaN     NaN
# 59        ROM    1.0          1.5        ROM     food   False
# 62  Ice Cream    1.0          1.5  ICE_CREAM     food   False
# 63      Pizza    2.5          4.0      PIZZA     food   False
#
#                        payback_account  payback_amount
# 11     Liabilities:Bar:Members:Marquis            0.50
# 14        Liabilities:Bar:Members:Bart            1.20
# 15  Liabilities:Bar:Members:NewlineJar            1.00
# 59     Liabilities:Bar:Members:Thequux            0.50
# 62        Liabilities:Bar:Members:Yvan            0.63
# 63        Liabilities:Bar:Members:Yvan            1.50

# %% [markdown]
# # Get recent values

# %%
df["date"] = pd.to_datetime(df["date"])  # Convert first
cutoff = pd.Timestamp.now() - pd.DateOffset(years=3)
recent_df = df[df["date"] >= cutoff]    # Then filter

# %%
recent_df
# Out:
#          transaction_id       date                              narration  \
# 69743   136912886701904 2022-06-02  Nachtvlinder bought 2 items for €2.60
# 69744   136912886701904 2022-06-02  Nachtvlinder bought 2 items for €2.60
# 69745   136912886701904 2022-06-02  Nachtvlinder bought 2 items for €2.60
# 69746   136912886701904 2022-06-02  Nachtvlinder bought 2 items for €2.60
# 69747   136912886701904 2022-06-02  Nachtvlinder bought 2 items for €2.60
# ...                 ...        ...                                    ...
# 100120  136912751826128 2025-05-29      Gust gave DJefke a gift of €41.70
# 100121  136912751826912 2025-05-29         Mateo bought 1 items for €1.50
# 100122  136912751826912 2025-05-29         Mateo bought 1 items for €1.50
# 100123  136912751826912 2025-05-29         Mateo bought 1 items for €1.50
# 100124  136912751826912 2025-05-29         Mateo bought 1 items for €1.50
#
#                                account   units currency      type
# 69743             Assets:Inventory:Bar      -1   BOUNTY  purchase
# 69744     Liabilities:Bar:Members:Maja       1   BOUNTY  purchase
# 69745             Assets:Inventory:Bar      -1    FRITZ  purchase
# 69746     Liabilities:Bar:Members:Maja       1    FRITZ  purchase
# 69747     Liabilities:Bar:Members:Maja    2.60      EUR  purchase
# ...                                ...     ...      ...       ...
# 100120  Liabilities:Bar:Members:DJefke  -41.70      EUR  transfer
# 100121            Assets:Inventory:Bar      -1     SODA  purchase
# 100122   Liabilities:Bar:Members:Mateo       1     SODA  purchase
# 100123   Liabilities:Bar:Members:Mateo    1.50      EUR  purchase
# 100124                      Income:Bar   -1.50      EUR  purchase
#
# [30382 rows x 7 columns]
